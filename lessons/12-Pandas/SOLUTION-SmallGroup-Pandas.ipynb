# %% [markdown]
# # Now You Code In Class: Tricks of The Pandas Masters
#
# We will try something a bit different in the Activity - A series of Pandas coding challenges!
#
#
# For this Now You Code, you will need the Zomato api https://developers.zomato.com/api which provides API access to local area restaurants information.

# %%
import pandas as pd
import import_ipynb
import googleapi as google
import requests

google_api_key = '751838d6b9978955679461c80a7df60bde4f093d'
# Out:
# importing Jupyter notebook from googleapi.ipynb

# %% [markdown]
# ## Warm-Up 1
#
# Load the following data set into a data frame, called `exam_df`
#
# https://raw.githubusercontent.com/mafudge/datasets/master/exam-scores/exam-scores.csv
#
# HINT: observe the file format!

# %%
exam_df = pd.read_csv('https://raw.githubusercontent.com/mafudge/datasets/master/exam-scores/exam-scores.csv')
exam_df
# Out:
#    Class_Section Exam_Version  Completion_Time Made_Own_Study_Guide  \
# 0            M01            A               20                    N
# 1            M01            A               20                    ?
# 2            M01            A               30                    Y
# 3            M01            A               50                    N
# 4            M01            A               55                    Y
# ..           ...          ...              ...                  ...
# 60           M02            D               40                    ?
# 61           M02            D               45                    Y
# 62           M02            D               45                    ?
# 63           M02            D               55                    Y
# 64           M02            D               60                    N
#
#    Did_Exam_Prep Assignment Studied_In_Groups  Student_Score Percentage  \
# 0                         N                 Y             24     80.00%
# 1                         ?                 ?             27     90.00%
# 2                         Y                 Y             30    100.00%
# 3                         Y                 Y             18     60.00%
# 4                         Y                 N             24     80.00%
# ..                      ...               ...            ...        ...
# 60                        ?                 ?             23     76.70%
# 61                        Y                 N             22     73.30%
# 62                        ?                 ?             24     80.00%
# 63                        Y                 N             24     80.00%
# 64                        N                 Y             24     80.00%
#
#    Letter_Grade
# 0             B
# 1            A-
# 2             A
# 3            C-
# 4             B
# ..          ...
# 60           B-
# 61           C+
# 62            B
# 63            B
# 64            B
#
# [65 rows x 9 columns]

# %% [markdown]
# ## Warm-Up 2
#
# Load the following HTML table into a data frame called `res_df`
#
# https://en.wikipedia.org/wiki/Graphics_display_resolution#High-definition
#
# HINT: Which table is it on the page?

# %%
res_df = pd.read_html('https://en.wikipedia.org/wiki/Graphics_display_resolution#High-definition')
df1 = res_df[4]

df1
# Out:
#    Height (px) Display aspect ratio[1]                                   \
#    Height (px)              1.25 (5∶4)   1.3 (4∶3)            1.5 (3∶2)
# 0          120                     NaN   160 QQVGA                  NaN
# 1          144                     NaN         192                  NaN
# 2          160                     NaN         NaN            240 HQVGA
# 3          240                     NaN    320 QVGA            360 WQVGA
# 4          320                     NaN         NaN             480 HVGA
# 5          360                     NaN         480                  NaN
# 6          480                     NaN     640 VGA             720 WVGA
# 7          540                     NaN         NaN                  NaN
# 8          576                     NaN     768 PAL                  NaN
# 9          600                     750    800 SVGA                  NaN
# 10         640                     NaN         NaN             960 DVGA
# 11         720                     NaN         960                  NaN
# 12         768                     960    1024 XGA            1152 WXGA
# 13         800                     NaN         NaN                  NaN
# 14         864                     NaN   1152 XGA+                 1280
# 15         900                     NaN        1200                  NaN
# 16         960                     NaN  1280 SXGA−          1440 FWXGA+
# 17        1024               1280 SXGA         NaN           1600 WSXGA
# 18        1050                     NaN  1400 SXGA+                  NaN
# 19        1080                     NaN        1440                  NaN
# 20        1152                     NaN         NaN                  NaN
# 21        1200                    1500   1600 UXGA                  NaN
# 22        1280                     NaN         NaN                 1920
# 23        1440                     NaN        1920            2160 FHD+
# 24        1536                     NaN   2048 QXGA                  NaN
# 25        1600                     NaN         NaN                 2400
# 26        1620                     NaN         NaN                  NaN
# 27        1800                     NaN         NaN                  NaN
# 28        1920                     NaN        2560                 2880
# 29        2048              2560 QSXGA        2732  3200 WQSXGA (25∶16)
# 30        2160                     NaN        2880                 3240
# 31        2400                     NaN  3200 QUXGA                  NaN
# 32        2560                     NaN         NaN                 3840
# 33        2880                     NaN         NaN                  NaN
# 34        3072                     NaN        4096                  NaN
# 35        4320                     NaN         NaN                  NaN
#
#                                                                      \
#             1.6 (16∶10)            1.6 (15∶9)            1.7 (16∶9)
# 0                   NaN                   NaN                   NaN
# 1                   NaN                   NaN                   256
# 2                   NaN                   NaN                   NaN
# 3             384 WQVGA             400 WQVGA      432 FWQVGA (9∶5)
# 4                   NaN                   NaN                   NaN
# 5                   NaN                   NaN               640 nHD
# 6              768 WVGA              800 WVGA             854 FWVGA
# 7                   NaN                   NaN               960 qHD
# 8                   NaN                   NaN            1024 WSVGA
# 9                   NaN  1024 WSVGA (≈ 17∶10)  1024 WSVGA (≈ 17∶10)
# 10                 1024                   NaN                  1136
# 11                 1152                   NaN        1280 HD / WXGA
# 12                  NaN             1280 WXGA            1366 FWXGA
# 13            1280 WXGA                   NaN                   NaN
# 14                  NaN                   NaN                  1536
# 15           1440 WXGA+                   NaN              1600 HD+
# 16                 1536                   NaN                   NaN
# 17                  NaN                   NaN                   NaN
# 18          1680 WSXGA+                   NaN                   NaN
# 19                  NaN                   NaN         1920 FHD / 2K
# 20                  NaN                   NaN            2048 QWXGA
# 21           1920 WUXGA                   NaN                   NaN
# 22                 2048                   NaN                   NaN
# 23                 2304                   NaN           2560 (W)QHD
# 24                  NaN                   NaN                   NaN
# 25           2560 WQXGA                   NaN                   NaN
# 26                  NaN                   NaN               2880 3K
# 27                 2880                   NaN             3200 QHD+
# 28                 3072                   NaN                   NaN
# 29  3200 WQSXGA (25∶16)                   NaN                   NaN
# 30                  NaN                   NaN           3840 4K UHD
# 31          3840 WQUXGA                   NaN                   NaN
# 32                 4096                   NaN                   NaN
# 33                  NaN                   NaN               5120 5K
# 34                  NaN                   NaN                   NaN
# 35                  NaN                   NaN           7680 8K UHD
#
#                                                        \
#                                            2.0 (18∶9)
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                           960 FWVGA
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                               1440
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                  2160, 2280 (19∶9)
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23  2880, 2960 (18.mw-parser-output .sfrac{white-s...
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                               4320
# 31                                                NaN
# 32                                                NaN
# 33                                               5760
# 34                                                NaN
# 35                                                NaN
#
#
#                            2.370 (64∶27 ≈ 21∶9)
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                                           NaN
# 8                                           NaN
# 9                                           NaN
# 10                                          NaN
# 11                                          NaN
# 12                                          NaN
# 13                                          NaN
# 14                                          NaN
# 15                                          NaN
# 16                                          NaN
# 17                                          NaN
# 18                                          NaN
# 19                                         2560
# 20                                          NaN
# 21                                          NaN
# 22                                          NaN
# 23  3120 (191/2∶9), 3200 (20∶9), 3440 (211/2∶9)
# 24                                          NaN
# 25                                  3840 (12∶5)
# 26                                          NaN
# 27                                          NaN
# 28                                          NaN
# 29                                          NaN
# 30                                         5120
# 31                                          NaN
# 32                                          NaN
# 33                                          NaN
# 34                                          NaN
# 35                                          NaN

# %% [markdown]
# ## Warm-Up 3
#
# For your `exam_df` display exams where the students made their own study guide  and finished in 30 minutes or less.
#
# HINT: This can be multiple steps

# %%
sg = exam_df[ exam_df['Made_Own_Study_Guide'] == 'Y']
sg[sg['Completion_Time'] <= 30]
# Out:
#    Class_Section Exam_Version  Completion_Time Made_Own_Study_Guide  \
# 2            M01            A               30                    Y
# 7            M01            B               15                    Y
# 9            M01            B               20                    Y
# 14           M01            C               20                    Y
# 48           M02            C               25                    Y
# 57           M02            D               20                    Y
#
#    Did_Exam_Prep Assignment Studied_In_Groups  Student_Score Percentage  \
# 2                         Y                 Y             30    100.00%
# 7                         Y                 Y             26     86.70%
# 9                         Y                 N             27     90.00%
# 14                        Y                 Y             26     86.70%
# 48                        Y                 Y             28     93.30%
# 57                        Y                 N             21     70.00%
#
#    Letter_Grade
# 2             A
# 7            B+
# 9            A-
# 14           B+
# 48           A-
# 57           C+

# %% [markdown]
# ## Warm-Up 4
#
# For your `res_df`, display the displays which are larger than 1920 x 1080. Show columns `Name` and `H:V` only
#
# HINT: Again, think multiple steps

# %%
df1[df1[('Height (px)','Height (px)')] >=1080 ]
# Out:
#    Height (px) Display aspect ratio[1]                                   \
#    Height (px)              1.25 (5∶4)   1.3 (4∶3)            1.5 (3∶2)
# 19        1080                     NaN        1440                  NaN
# 20        1152                     NaN         NaN                  NaN
# 21        1200                    1500   1600 UXGA                  NaN
# 22        1280                     NaN         NaN                 1920
# 23        1440                     NaN        1920            2160 FHD+
# 24        1536                     NaN   2048 QXGA                  NaN
# 25        1600                     NaN         NaN                 2400
# 26        1620                     NaN         NaN                  NaN
# 27        1800                     NaN         NaN                  NaN
# 28        1920                     NaN        2560                 2880
# 29        2048              2560 QSXGA        2732  3200 WQSXGA (25∶16)
# 30        2160                     NaN        2880                 3240
# 31        2400                     NaN  3200 QUXGA                  NaN
# 32        2560                     NaN         NaN                 3840
# 33        2880                     NaN         NaN                  NaN
# 34        3072                     NaN        4096                  NaN
# 35        4320                     NaN         NaN                  NaN
#
#                                                    \
#             1.6 (16∶10) 1.6 (15∶9)     1.7 (16∶9)
# 19                  NaN        NaN  1920 FHD / 2K
# 20                  NaN        NaN     2048 QWXGA
# 21           1920 WUXGA        NaN            NaN
# 22                 2048        NaN            NaN
# 23                 2304        NaN    2560 (W)QHD
# 24                  NaN        NaN            NaN
# 25           2560 WQXGA        NaN            NaN
# 26                  NaN        NaN        2880 3K
# 27                 2880        NaN      3200 QHD+
# 28                 3072        NaN            NaN
# 29  3200 WQSXGA (25∶16)        NaN            NaN
# 30                  NaN        NaN    3840 4K UHD
# 31          3840 WQUXGA        NaN            NaN
# 32                 4096        NaN            NaN
# 33                  NaN        NaN        5120 5K
# 34                  NaN        NaN            NaN
# 35                  NaN        NaN    7680 8K UHD
#
#                                                        \
#                                            2.0 (18∶9)
# 19                                  2160, 2280 (19∶9)
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23  2880, 2960 (18.mw-parser-output .sfrac{white-s...
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                               4320
# 31                                                NaN
# 32                                                NaN
# 33                                               5760
# 34                                                NaN
# 35                                                NaN
#
#
#                            2.370 (64∶27 ≈ 21∶9)
# 19                                         2560
# 20                                          NaN
# 21                                          NaN
# 22                                          NaN
# 23  3120 (191/2∶9), 3200 (20∶9), 3440 (211/2∶9)
# 24                                          NaN
# 25                                  3840 (12∶5)
# 26                                          NaN
# 27                                          NaN
# 28                                          NaN
# 29                                          NaN
# 30                                         5120
# 31                                          NaN
# 32                                          NaN
# 33                                          NaN
# 34                                          NaN
# 35                                          NaN

# %% [markdown]
# ## Challenge 1
#
# 1. Search the Open Street Maps  geocode api for "Syracuse" (leave off the NY) put the results in a dataframe (there should be several results).
#
# Example:
# https://nominatim.openstreetmap.org/search?q=Syracuse&format=json

# %%
response = requests.get("https://nominatim.openstreetmap.org/search?q=Syracuse&format=json")
response.raise_for_status()
data = response.json()
# Out:
# [{'place_id': 257841956,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 174916,
#   'boundingbox': ['42.9843709', '43.086102', '-76.2046029', '-76.074084'],
#   'lat': '43.0481221',
#   'lon': '-76.1474244',
#   'display_name': 'Syracuse, Onondaga County, New York, United States',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.6867762857760726,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png'},
#  {'place_id': 257728182,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 39169,
#   'boundingbox': ['36.9477054', '37.1156703', '15.0829726', '15.3367251'],
#   'lat': '37.0646139',
#   'lon': '15.2907196',
#   'display_name': 'Siracusa, Sicilia, Italia',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.5980544326919952,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png'},
#  {'place_id': 257785961,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 129906,
#   'boundingbox': ['37.941272', '37.990492', '-101.816776', '-101.736708'],
#   'lat': '37.9805686',
#   'lon': '-101.7526719',
#   'display_name': 'Syracuse, Hamilton County, Kansas, 67878, United States',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.5354945081461472,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png'},
#  {'place_id': 257190791,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 169314,
#   'boundingbox': ['40.651206', '40.672865', '-96.197821', '-96.172004'],
#   'lat': '40.657224',
#   'lon': '-96.186398',
#   'display_name': 'Syracuse, Otoe County, Nebraska, United States',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.46112554102268,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png'},
#  {'place_id': 258183983,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 198737,
#   'boundingbox': ['41.0529648', '41.11093', '-112.1159667', '-112.035662'],
#   'lat': '41.0895938',
#   'lon': '-112.0638903',
#   'display_name': 'Syracuse, Davis County, Utah, 84075, United States',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.436855406087553,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png'},
#  {'place_id': 69010415,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'node',
#   'osm_id': 6241108067,
#   'boundingbox': ['43.0718312', '43.0818312', '-76.1744003', '-76.1644003'],
#   'lat': '43.0768312',
#   'lon': '-76.1694003',
#   'display_name': 'Syracuse, 131, NBT Bank Parkway, Syracuse, Onondaga County, New York, 13208, United States',
#   'class': 'railway',
#   'type': 'station',
#   'importance': 0.4272524353626238,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//transport_train_station2.p.20.png'},
#  {'place_id': 257152602,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 141314,
#   'boundingbox': ['38.665793', '38.67337', '-92.883419', '-92.869404'],
#   'lat': '38.6700209',
#   'lon': '-92.8732509',
#   'display_name': 'Syracuse, Morgan County, Missouri, United States',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.42043947441223084,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png'},
#  {'place_id': 257782630,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 127610,
#   'boundingbox': ['41.403028', '41.43607', '-85.768612', '-85.734116'],
#   'lat': '41.4278409',
#   'lon': '-85.7524957',
#   'display_name': 'Syracuse, Kosciusko County, Indiana, United States',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.42043947441223084,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png'},
#  {'place_id': 258361658,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 182667,
#   'boundingbox': ['38.9922728', '39.007177', '-81.9841277', '-81.943146'],
#   'lat': '38.9975789',
#   'lon': '-81.9740274',
#   'display_name': 'Syracuse, Meigs County, Ohio, 45779, United States',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.4090422669932742,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png'},
#  {'place_id': 257738503,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 39155,
#   'boundingbox': ['36.6441671', '37.4128826', '14.7729261', '15.3367251'],
#   'lat': '37.02983715',
#   'lon': '15.086780069913484',
#   'display_name': 'Siracusa, Sicilia, Italia',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.4042848260470168,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png'}]

# %% [markdown]
# ## Challenge 2
#
# 1. Load the places into a dataframe. using the `pd.DataFrame()` method. Start with whatever is of type `list` as that will automatically place it into a `DataFrame`

# %%
pdf = pd.DataFrame(data)
pdf
# Out:
#     place_id                                            licence  osm_type  \
# 0  257841956  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 1  257728182  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 2  257785961  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 3  257190791  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 4  258183983  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 5   69010415  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 6  257152602  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 7  257782630  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 8  258361658  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 9  257738503  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
#
#        osm_id                                        boundingbox          lat  \
# 0      174916   [42.9843709, 43.086102, -76.2046029, -76.074084]   43.0481221
# 1       39169   [36.9477054, 37.1156703, 15.0829726, 15.3367251]   37.0646139
# 2      129906   [37.941272, 37.990492, -101.816776, -101.736708]   37.9805686
# 3      169314     [40.651206, 40.672865, -96.197821, -96.172004]    40.657224
# 4      198737  [41.0529648, 41.11093, -112.1159667, -112.035662]   41.0895938
# 5  6241108067  [43.0718312, 43.0818312, -76.1744003, -76.1644...   43.0768312
# 6      141314      [38.665793, 38.67337, -92.883419, -92.869404]   38.6700209
# 7      127610      [41.403028, 41.43607, -85.768612, -85.734116]   41.4278409
# 8      182667   [38.9922728, 39.007177, -81.9841277, -81.943146]   38.9975789
# 9       39155   [36.6441671, 37.4128826, 14.7729261, 15.3367251]  37.02983715
#
#                   lon                                       display_name  \
# 0         -76.1474244  Syracuse, Onondaga County, New York, United St...
# 1          15.2907196                          Siracusa, Sicilia, Italia
# 2        -101.7526719  Syracuse, Hamilton County, Kansas, 67878, Unit...
# 3          -96.186398     Syracuse, Otoe County, Nebraska, United States
# 4        -112.0638903  Syracuse, Davis County, Utah, 84075, United St...
# 5         -76.1694003  Syracuse, 131, NBT Bank Parkway, Syracuse, Ono...
# 6         -92.8732509   Syracuse, Morgan County, Missouri, United States
# 7         -85.7524957  Syracuse, Kosciusko County, Indiana, United St...
# 8         -81.9740274  Syracuse, Meigs County, Ohio, 45779, United St...
# 9  15.086780069913484                          Siracusa, Sicilia, Italia
#
#       class            type  importance  \
# 0  boundary  administrative    0.686776
# 1  boundary  administrative    0.598054
# 2  boundary  administrative    0.535495
# 3  boundary  administrative    0.461126
# 4  boundary  administrative    0.436855
# 5   railway         station    0.427252
# 6  boundary  administrative    0.420439
# 7  boundary  administrative    0.420439
# 8  boundary  administrative    0.409042
# 9  boundary  administrative    0.404285
#
#                                                 icon
# 0  https://nominatim.openstreetmap.org/ui/mapicon...
# 1  https://nominatim.openstreetmap.org/ui/mapicon...
# 2  https://nominatim.openstreetmap.org/ui/mapicon...
# 3  https://nominatim.openstreetmap.org/ui/mapicon...
# 4  https://nominatim.openstreetmap.org/ui/mapicon...
# 5  https://nominatim.openstreetmap.org/ui/mapicon...
# 6  https://nominatim.openstreetmap.org/ui/mapicon...
# 7  https://nominatim.openstreetmap.org/ui/mapicon...
# 8  https://nominatim.openstreetmap.org/ui/mapicon...
# 9  https://nominatim.openstreetmap.org/ui/mapicon...

# %% [markdown]
# ## Challenge 3
#
# 1. Let's call the IST256 google places search api, looking for bars in the Syracuse NY area, and load the results into a dataframe. You can call `google.googlePlacesSearch()` With these inputs lat=`43.0481`, lng=`-76.1474`, type=`'bar'`

# %%
data = google.googlePlacesSearch(lat=43.0481, lng=-76.1474,place_type='bar',google_api_key=google_api_key)

gdf = pd.DataFrame(data)
gdf
# Out:
#        business_status                                           geometry  \
# 0          OPERATIONAL  {'location': {'lat': 43.0485021, 'lng': -76.15...
# 1          OPERATIONAL  {'location': {'lat': 43.04672, 'lng': -76.1375...
# 2          OPERATIONAL  {'location': {'lat': 43.0478305, 'lng': -76.15...
# 3          OPERATIONAL  {'location': {'lat': 43.0418639, 'lng': -76.13...
# 4   CLOSED_TEMPORARILY  {'location': {'lat': 43.0481128, 'lng': -76.15...
# 5          OPERATIONAL  {'location': {'lat': 43.05074, 'lng': -76.1545...
# 6          OPERATIONAL  {'location': {'lat': 43.048176, 'lng': -76.153...
# 7          OPERATIONAL  {'location': {'lat': 43.052942, 'lng': -76.153...
# 8          OPERATIONAL  {'location': {'lat': 43.05237700000001, 'lng':...
# 9          OPERATIONAL  {'location': {'lat': 43.0481533, 'lng': -76.15...
# 10         OPERATIONAL  {'location': {'lat': 43.05012019999999, 'lng':...
# 11         OPERATIONAL  {'location': {'lat': 43.04941199999999, 'lng':...
# 12         OPERATIONAL  {'location': {'lat': 43.05069699999999, 'lng':...
# 13         OPERATIONAL  {'location': {'lat': 43.0476609, 'lng': -76.14...
# 14         OPERATIONAL  {'location': {'lat': 43.048347, 'lng': -76.153...
# 15         OPERATIONAL  {'location': {'lat': 43.0444715, 'lng': -76.15...
# 16         OPERATIONAL  {'location': {'lat': 43.0485311, 'lng': -76.15...
# 17         OPERATIONAL  {'location': {'lat': 43.0442185, 'lng': -76.14...
# 18         OPERATIONAL  {'location': {'lat': 43.04758830000001, 'lng':...
# 19         OPERATIONAL  {'location': {'lat': 43.04852869999999, 'lng':...
#
#                                                  icon  \
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...
# 5   https://maps.gstatic.com/mapfiles/place_api/ic...
# 6   https://maps.gstatic.com/mapfiles/place_api/ic...
# 7   https://maps.gstatic.com/mapfiles/place_api/ic...
# 8   https://maps.gstatic.com/mapfiles/place_api/ic...
# 9   https://maps.gstatic.com/mapfiles/place_api/ic...
# 10  https://maps.gstatic.com/mapfiles/place_api/ic...
# 11  https://maps.gstatic.com/mapfiles/place_api/ic...
# 12  https://maps.gstatic.com/mapfiles/place_api/ic...
# 13  https://maps.gstatic.com/mapfiles/place_api/ic...
# 14  https://maps.gstatic.com/mapfiles/place_api/ic...
# 15  https://maps.gstatic.com/mapfiles/place_api/ic...
# 16  https://maps.gstatic.com/mapfiles/place_api/ic...
# 17  https://maps.gstatic.com/mapfiles/place_api/ic...
# 18  https://maps.gstatic.com/mapfiles/place_api/ic...
# 19  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                    name        opening_hours  \
# 0               Kitty Hoyne's Irish Pub   {'open_now': True}
# 1   Phoebe's Restaurant & Coffee Lounge  {'open_now': False}
# 2                             Blue Tusk   {'open_now': True}
# 3                   Faegan's Cafe & Pub  {'open_now': False}
# 4                 Syracuse Suds Factory                  NaN
# 5            Saltine Warrior Sports Pub   {'open_now': True}
# 6            Al's Wine & Whiskey Lounge  {'open_now': False}
# 7                                 Trexx  {'open_now': False}
# 8                  Guilfoil's Irish Pub   {'open_now': True}
# 9                         The Hops Spot  {'open_now': False}
# 10                             Maxwells  {'open_now': False}
# 11                    Anything But Beer  {'open_now': False}
# 12                        The Evergreen  {'open_now': False}
# 13                     Weighlock Lounge  {'open_now': False}
# 14                      Funk 'n Waffles   {'open_now': True}
# 15              Shaughnessy's Irish Pub  {'open_now': False}
# 16                             The York  {'open_now': False}
# 17                    Ale 'n' Angus Pub   {'open_now': True}
# 18                      Bistro Elephant                  NaN
# 19                   Clinton Street Pub  {'open_now': False}
#
#                                                photos  \
# 0   [{'height': 3024, 'html_attributions': ['<a hr...
# 1   [{'height': 4032, 'html_attributions': ['<a hr...
# 2   [{'height': 1366, 'html_attributions': ['<a hr...
# 3   [{'height': 1210, 'html_attributions': ['<a hr...
# 4   [{'height': 2666, 'html_attributions': ['<a hr...
# 5   [{'height': 1000, 'html_attributions': ['<a hr...
# 6   [{'height': 3024, 'html_attributions': ['<a hr...
# 7   [{'height': 3024, 'html_attributions': ['<a hr...
# 8   [{'height': 452, 'html_attributions': ['<a hre...
# 9   [{'height': 3024, 'html_attributions': ['<a hr...
# 10  [{'height': 1960, 'html_attributions': ['<a hr...
# 11  [{'height': 922, 'html_attributions': ['<a hre...
# 12  [{'height': 1169, 'html_attributions': ['<a hr...
# 13  [{'height': 1920, 'html_attributions': ['<a hr...
# 14  [{'height': 381, 'html_attributions': ['<a hre...
# 15  [{'height': 4016, 'html_attributions': ['<a hr...
# 16  [{'height': 3024, 'html_attributions': ['<a hr...
# 17  [{'height': 4032, 'html_attributions': ['<a hr...
# 18  [{'height': 1365, 'html_attributions': ['<a hr...
# 19  [{'height': 4032, 'html_attributions': ['<a hr...
#
#                        place_id  \
# 0   ChIJ2abhW8fz2YkRq_i-OkgGh7c
# 1   ChIJ4XPPn6bz2YkRKrZtWuXTaA0
# 2   ChIJYcGiq7jz2YkR2Ah1e3mkNOg
# 3   ChIJn5r_W5_z2YkR67VB2u5qyRw
# 4   ChIJ42EzyLjz2YkRz4aKaDCeDbw
# 5   ChIJ4eXBZ7jz2YkRWwzq6jh85dM
# 6   ChIJVfyEyLjz2YkRf7FRJXkhgd0
# 7   ChIJnRi-jbfz2YkRBpeSSVhhMxE
# 8   ChIJDfWlPa_z2YkRHNJzLnjnILM
# 9   ChIJvfSLcA0T2IkRfWBTZpwlidY
# 10  ChIJM86Fpbnz2YkRKrGFqtQqBi8
# 11  ChIJgRICEd7z2YkREtShfi5Pgzo
# 12  ChIJHegrubnz2YkRoEpk_R7BDTg
# 13  ChIJ2SNg6aTz2YkRa1B-BaUA2rA
# 14  ChIJLX-Pxrjz2YkRLe-7F_VN3HE
# 15  ChIJo8R5WL7z2YkRRcysmcsM3yo
# 16  ChIJJdSLp7jz2YkRLDrtGu98O-M
# 17  ChIJJa942r3z2YkREJnXnrSTZK0
# 18  ChIJL0sWVL_z2YkRQhZzBYHjmPs
# 19  ChIJvwKdwbjz2YkR2pHlLXgBxek
#
#                                             plus_code  price_level  rating  \
# 0   {'compound_code': '2RXV+CM Syracuse, NY, USA',...          2.0     4.6
# 1   {'compound_code': '2VW6+MX Syracuse, NY, USA',...          2.0     4.6
# 2   {'compound_code': '2RXW+44 Syracuse, NY, USA',...          2.0     4.4
# 3   {'compound_code': '2VR7+P7 Syracuse, NY, USA',...          2.0     4.3
# 4   {'compound_code': '2RXW+6C Syracuse, NY, USA',...          2.0     3.3
# 5   {'compound_code': '3R2W+75 Syracuse, NY, USA',...          2.0     4.0
# 6   {'compound_code': '2RXW+7M Syracuse, NY, USA',...          2.0     4.6
# 7   {'compound_code': '3R3W+5F Syracuse, NY, USA',...          1.0     4.1
# 8   {'compound_code': '3V26+XC Syracuse, NY, USA',...          1.0     4.6
# 9   {'compound_code': '2RXW+76 Syracuse, NY, USA',...          2.0     4.4
# 10  {'compound_code': '3R2X+29 Syracuse, NY, USA',...          2.0     4.3
# 11  {'compound_code': '2RXX+Q5 Syracuse, NY, USA',...          NaN     4.5
# 12  {'compound_code': '3R2X+7F Syracuse, NY, USA',...          2.0     4.5
# 13  {'compound_code': '2VX5+36 Syracuse, NY, USA',...          NaN     4.8
# 14  {'compound_code': '2RXW+8M Syracuse, NY, USA',...          NaN     4.4
# 15  {'compound_code': '2RVX+QH Syracuse, NY, USA',...          2.0     4.1
# 16  {'compound_code': '2RXV+CX Syracuse, NY, USA',...          2.0     4.3
# 17  {'compound_code': '2VV2+M9 Syracuse, NY, USA',...          2.0     4.5
# 18  {'compound_code': '2RXW+25 Syracuse, NY, USA',...          NaN     4.4
# 19  {'compound_code': '2RXW+CJ Syracuse, NY, USA',...          1.0     4.0
#
#                       reference   scope  \
# 0   ChIJ2abhW8fz2YkRq_i-OkgGh7c  GOOGLE
# 1   ChIJ4XPPn6bz2YkRKrZtWuXTaA0  GOOGLE
# 2   ChIJYcGiq7jz2YkR2Ah1e3mkNOg  GOOGLE
# 3   ChIJn5r_W5_z2YkR67VB2u5qyRw  GOOGLE
# 4   ChIJ42EzyLjz2YkRz4aKaDCeDbw  GOOGLE
# 5   ChIJ4eXBZ7jz2YkRWwzq6jh85dM  GOOGLE
# 6   ChIJVfyEyLjz2YkRf7FRJXkhgd0  GOOGLE
# 7   ChIJnRi-jbfz2YkRBpeSSVhhMxE  GOOGLE
# 8   ChIJDfWlPa_z2YkRHNJzLnjnILM  GOOGLE
# 9   ChIJvfSLcA0T2IkRfWBTZpwlidY  GOOGLE
# 10  ChIJM86Fpbnz2YkRKrGFqtQqBi8  GOOGLE
# 11  ChIJgRICEd7z2YkREtShfi5Pgzo  GOOGLE
# 12  ChIJHegrubnz2YkRoEpk_R7BDTg  GOOGLE
# 13  ChIJ2SNg6aTz2YkRa1B-BaUA2rA  GOOGLE
# 14  ChIJLX-Pxrjz2YkRLe-7F_VN3HE  GOOGLE
# 15  ChIJo8R5WL7z2YkRRcysmcsM3yo  GOOGLE
# 16  ChIJJdSLp7jz2YkRLDrtGu98O-M  GOOGLE
# 17  ChIJJa942r3z2YkREJnXnrSTZK0  GOOGLE
# 18  ChIJL0sWVL_z2YkRQhZzBYHjmPs  GOOGLE
# 19  ChIJvwKdwbjz2YkR2pHlLXgBxek  GOOGLE
#
#                                                 types  user_ratings_total  \
# 0   [bar, restaurant, food, point_of_interest, est...                1246
# 1   [meal_takeaway, cafe, bar, restaurant, food, p...                 485
# 2   [bar, restaurant, food, point_of_interest, est...                 707
# 3   [cafe, bar, restaurant, food, point_of_interes...                 428
# 4             [bar, point_of_interest, establishment]                 140
# 5   [bar, restaurant, food, point_of_interest, est...                 119
# 6             [bar, point_of_interest, establishment]                 699
# 7   [night_club, bar, restaurant, food, point_of_i...                  66
# 8   [bar, restaurant, food, point_of_interest, est...                 144
# 9   [bar, liquor_store, restaurant, food, point_of...                 444
# 10  [bar, restaurant, food, point_of_interest, est...                 279
# 11  [restaurant, meal_delivery, bar, food, point_o...                  70
# 12  [bar, restaurant, food, point_of_interest, est...                 552
# 13            [bar, point_of_interest, establishment]                   4
# 14  [cafe, bar, restaurant, food, point_of_interes...                1736
# 15  [bar, restaurant, food, point_of_interest, est...                 530
# 16  [night_club, bar, restaurant, food, point_of_i...                 373
# 17            [bar, point_of_interest, establishment]                 382
# 18  [bar, restaurant, food, point_of_interest, est...                  34
# 19  [bar, restaurant, food, point_of_interest, est...                 403
#
#                                      vicinity permanently_closed
# 0           301 West Fayette Street, Syracuse                NaN
# 1           900 East Genesee Street, Syracuse                NaN
# 2                 165 Walton Street, Syracuse                NaN
# 3           734 South Crouse Avenue, Syracuse                NaN
# 4          320 South Clinton Street, Syracuse               True
# 5             214 West Water Street, Syracuse                NaN
# 6          321 South Clinton Street, Syracuse                NaN
# 7          323 North Clinton Street, Syracuse                NaN
# 8                 501 Burnet Avenue, Syracuse                NaN
# 9                 116 Walton Street, Syracuse                NaN
# 10          122 East Genesee Street, Syracuse                NaN
# 11          201 South Salina Street, Syracuse                NaN
# 12            125 East Water Street, Syracuse                NaN
# 13  701 East Genesee Street suite b, Syracuse                NaN
# 14      307-13 South Clinton Street, Syracuse                NaN
# 15          550 South Warren Street, Syracuse                NaN
# 16          247 West Fayette Street, Syracuse                NaN
# 17              238 Harrison Street, Syracuse                NaN
# 18        238 West Jefferson Street, Syracuse                NaN
# 19          127 West Fayette Street, Syracuse                NaN

# %% [markdown]
# ## Challenge 4
#
# Notice the nested JSON. Yuk. This can be fixed using `pd.json_normalize` instead of `pd.DataFrame`.
#
# Fix the results above so that the nested JSON is flattened in the dataframe.

# %%
flat_gdf = pd.json_normalize(data)
flat_gdf
# Out:
#        business_status                                               icon  \
# 0          OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1          OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2          OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3          OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4   CLOSED_TEMPORARILY  https://maps.gstatic.com/mapfiles/place_api/ic...
# 5          OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 6          OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 7          OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 8          OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 9          OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 10         OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 11         OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 12         OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 13         OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 14         OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 15         OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 16         OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 17         OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 18         OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 19         OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                    name  \
# 0               Kitty Hoyne's Irish Pub
# 1   Phoebe's Restaurant & Coffee Lounge
# 2                             Blue Tusk
# 3                   Faegan's Cafe & Pub
# 4                 Syracuse Suds Factory
# 5            Saltine Warrior Sports Pub
# 6            Al's Wine & Whiskey Lounge
# 7                                 Trexx
# 8                  Guilfoil's Irish Pub
# 9                         The Hops Spot
# 10                             Maxwells
# 11                    Anything But Beer
# 12                        The Evergreen
# 13                     Weighlock Lounge
# 14                      Funk 'n Waffles
# 15              Shaughnessy's Irish Pub
# 16                             The York
# 17                    Ale 'n' Angus Pub
# 18                      Bistro Elephant
# 19                   Clinton Street Pub
#
#                                                photos  \
# 0   [{'height': 3024, 'html_attributions': ['<a hr...
# 1   [{'height': 4032, 'html_attributions': ['<a hr...
# 2   [{'height': 1366, 'html_attributions': ['<a hr...
# 3   [{'height': 1210, 'html_attributions': ['<a hr...
# 4   [{'height': 2666, 'html_attributions': ['<a hr...
# 5   [{'height': 1000, 'html_attributions': ['<a hr...
# 6   [{'height': 3024, 'html_attributions': ['<a hr...
# 7   [{'height': 3024, 'html_attributions': ['<a hr...
# 8   [{'height': 452, 'html_attributions': ['<a hre...
# 9   [{'height': 3024, 'html_attributions': ['<a hr...
# 10  [{'height': 1960, 'html_attributions': ['<a hr...
# 11  [{'height': 922, 'html_attributions': ['<a hre...
# 12  [{'height': 1169, 'html_attributions': ['<a hr...
# 13  [{'height': 1920, 'html_attributions': ['<a hr...
# 14  [{'height': 381, 'html_attributions': ['<a hre...
# 15  [{'height': 4016, 'html_attributions': ['<a hr...
# 16  [{'height': 3024, 'html_attributions': ['<a hr...
# 17  [{'height': 4032, 'html_attributions': ['<a hr...
# 18  [{'height': 1365, 'html_attributions': ['<a hr...
# 19  [{'height': 4032, 'html_attributions': ['<a hr...
#
#                        place_id  price_level  rating  \
# 0   ChIJ2abhW8fz2YkRq_i-OkgGh7c          2.0     4.6
# 1   ChIJ4XPPn6bz2YkRKrZtWuXTaA0          2.0     4.6
# 2   ChIJYcGiq7jz2YkR2Ah1e3mkNOg          2.0     4.4
# 3   ChIJn5r_W5_z2YkR67VB2u5qyRw          2.0     4.3
# 4   ChIJ42EzyLjz2YkRz4aKaDCeDbw          2.0     3.3
# 5   ChIJ4eXBZ7jz2YkRWwzq6jh85dM          2.0     4.0
# 6   ChIJVfyEyLjz2YkRf7FRJXkhgd0          2.0     4.6
# 7   ChIJnRi-jbfz2YkRBpeSSVhhMxE          1.0     4.1
# 8   ChIJDfWlPa_z2YkRHNJzLnjnILM          1.0     4.6
# 9   ChIJvfSLcA0T2IkRfWBTZpwlidY          2.0     4.4
# 10  ChIJM86Fpbnz2YkRKrGFqtQqBi8          2.0     4.3
# 11  ChIJgRICEd7z2YkREtShfi5Pgzo          NaN     4.5
# 12  ChIJHegrubnz2YkRoEpk_R7BDTg          2.0     4.5
# 13  ChIJ2SNg6aTz2YkRa1B-BaUA2rA          NaN     4.8
# 14  ChIJLX-Pxrjz2YkRLe-7F_VN3HE          NaN     4.4
# 15  ChIJo8R5WL7z2YkRRcysmcsM3yo          2.0     4.1
# 16  ChIJJdSLp7jz2YkRLDrtGu98O-M          2.0     4.3
# 17  ChIJJa942r3z2YkREJnXnrSTZK0          2.0     4.5
# 18  ChIJL0sWVL_z2YkRQhZzBYHjmPs          NaN     4.4
# 19  ChIJvwKdwbjz2YkR2pHlLXgBxek          1.0     4.0
#
#                       reference   scope  \
# 0   ChIJ2abhW8fz2YkRq_i-OkgGh7c  GOOGLE
# 1   ChIJ4XPPn6bz2YkRKrZtWuXTaA0  GOOGLE
# 2   ChIJYcGiq7jz2YkR2Ah1e3mkNOg  GOOGLE
# 3   ChIJn5r_W5_z2YkR67VB2u5qyRw  GOOGLE
# 4   ChIJ42EzyLjz2YkRz4aKaDCeDbw  GOOGLE
# 5   ChIJ4eXBZ7jz2YkRWwzq6jh85dM  GOOGLE
# 6   ChIJVfyEyLjz2YkRf7FRJXkhgd0  GOOGLE
# 7   ChIJnRi-jbfz2YkRBpeSSVhhMxE  GOOGLE
# 8   ChIJDfWlPa_z2YkRHNJzLnjnILM  GOOGLE
# 9   ChIJvfSLcA0T2IkRfWBTZpwlidY  GOOGLE
# 10  ChIJM86Fpbnz2YkRKrGFqtQqBi8  GOOGLE
# 11  ChIJgRICEd7z2YkREtShfi5Pgzo  GOOGLE
# 12  ChIJHegrubnz2YkRoEpk_R7BDTg  GOOGLE
# 13  ChIJ2SNg6aTz2YkRa1B-BaUA2rA  GOOGLE
# 14  ChIJLX-Pxrjz2YkRLe-7F_VN3HE  GOOGLE
# 15  ChIJo8R5WL7z2YkRRcysmcsM3yo  GOOGLE
# 16  ChIJJdSLp7jz2YkRLDrtGu98O-M  GOOGLE
# 17  ChIJJa942r3z2YkREJnXnrSTZK0  GOOGLE
# 18  ChIJL0sWVL_z2YkRQhZzBYHjmPs  GOOGLE
# 19  ChIJvwKdwbjz2YkR2pHlLXgBxek  GOOGLE
#
#                                                 types  ...  \
# 0   [bar, restaurant, food, point_of_interest, est...  ...
# 1   [meal_takeaway, cafe, bar, restaurant, food, p...  ...
# 2   [bar, restaurant, food, point_of_interest, est...  ...
# 3   [cafe, bar, restaurant, food, point_of_interes...  ...
# 4             [bar, point_of_interest, establishment]  ...
# 5   [bar, restaurant, food, point_of_interest, est...  ...
# 6             [bar, point_of_interest, establishment]  ...
# 7   [night_club, bar, restaurant, food, point_of_i...  ...
# 8   [bar, restaurant, food, point_of_interest, est...  ...
# 9   [bar, liquor_store, restaurant, food, point_of...  ...
# 10  [bar, restaurant, food, point_of_interest, est...  ...
# 11  [restaurant, meal_delivery, bar, food, point_o...  ...
# 12  [bar, restaurant, food, point_of_interest, est...  ...
# 13            [bar, point_of_interest, establishment]  ...
# 14  [cafe, bar, restaurant, food, point_of_interes...  ...
# 15  [bar, restaurant, food, point_of_interest, est...  ...
# 16  [night_club, bar, restaurant, food, point_of_i...  ...
# 17            [bar, point_of_interest, establishment]  ...
# 18  [bar, restaurant, food, point_of_interest, est...  ...
# 19  [bar, restaurant, food, point_of_interest, est...  ...
#
#     geometry.location.lat geometry.location.lng  \
# 0               43.048502            -76.155753
# 1               43.046720            -76.137567
# 2               43.047831            -76.154710
# 3               43.041864            -76.136842
# 4               43.048113            -76.153888
# 5               43.050740            -76.154507
# 6               43.048176            -76.153368
# 7               43.052942            -76.153755
# 8               43.052377            -76.138954
# 9               43.048153            -76.154417
# 10              43.050120            -76.151505
# 11              43.049412            -76.152007
# 12              43.050697            -76.151272
# 13              43.047661            -76.141877
# 14              43.048347            -76.153270
# 15              43.044472            -76.151072
# 16              43.048531            -76.155064
# 17              43.044218            -76.149062
# 18              43.047588            -76.154541
# 19              43.048529            -76.153391
#
#     geometry.viewport.northeast.lat  geometry.viewport.northeast.lng  \
# 0                         43.049959                       -76.154394
# 1                         43.048037                       -76.136307
# 2                         43.049179                       -76.153361
# 3                         43.043212                       -76.135400
# 4                         43.049476                       -76.152380
# 5                         43.052089                       -76.153158
# 6                         43.049546                       -76.152121
# 7                         43.054332                       -76.152522
# 8                         43.053638                       -76.137607
# 9                         43.049409                       -76.153082
# 10                        43.051580                       -76.150072
# 11                        43.050773                       -76.150762
# 12                        43.052143                       -76.149912
# 13                        43.049085                       -76.140664
# 14                        43.049704                       -76.152074
# 15                        43.045751                       -76.149781
# 16                        43.049970                       -76.153714
# 17                        43.045614                       -76.147714
# 18                        43.048854                       -76.153143
# 19                        43.049871                       -76.152135
#
#     geometry.viewport.southwest.lat  geometry.viewport.southwest.lng  \
# 0                         43.047261                       -76.157092
# 1                         43.045339                       -76.139005
# 2                         43.046482                       -76.156059
# 3                         43.040514                       -76.138098
# 4                         43.046778                       -76.155078
# 5                         43.049391                       -76.155856
# 6                         43.046848                       -76.154819
# 7                         43.051634                       -76.155220
# 8                         43.050940                       -76.140305
# 9                         43.046711                       -76.155780
# 10                        43.048882                       -76.152770
# 11                        43.048075                       -76.153460
# 12                        43.049445                       -76.152610
# 13                        43.046387                       -76.143362
# 14                        43.047006                       -76.154771
# 15                        43.043053                       -76.152478
# 16                        43.047272                       -76.156412
# 17                        43.042916                       -76.150412
# 18                        43.046156                       -76.155841
# 19                        43.047173                       -76.154833
#
#     opening_hours.open_now    plus_code.compound_code plus_code.global_code  \
# 0                     True  2RXV+CM Syracuse, NY, USA           87M52RXV+CM
# 1                    False  2VW6+MX Syracuse, NY, USA           87M52VW6+MX
# 2                     True  2RXW+44 Syracuse, NY, USA           87M52RXW+44
# 3                    False  2VR7+P7 Syracuse, NY, USA           87M52VR7+P7
# 4                      NaN  2RXW+6C Syracuse, NY, USA           87M52RXW+6C
# 5                     True  3R2W+75 Syracuse, NY, USA           87M53R2W+75
# 6                    False  2RXW+7M Syracuse, NY, USA           87M52RXW+7M
# 7                    False  3R3W+5F Syracuse, NY, USA           87M53R3W+5F
# 8                     True  3V26+XC Syracuse, NY, USA           87M53V26+XC
# 9                    False  2RXW+76 Syracuse, NY, USA           87M52RXW+76
# 10                   False  3R2X+29 Syracuse, NY, USA           87M53R2X+29
# 11                   False  2RXX+Q5 Syracuse, NY, USA           87M52RXX+Q5
# 12                   False  3R2X+7F Syracuse, NY, USA           87M53R2X+7F
# 13                   False  2VX5+36 Syracuse, NY, USA           87M52VX5+36
# 14                    True  2RXW+8M Syracuse, NY, USA           87M52RXW+8M
# 15                   False  2RVX+QH Syracuse, NY, USA           87M52RVX+QH
# 16                   False  2RXV+CX Syracuse, NY, USA           87M52RXV+CX
# 17                    True  2VV2+M9 Syracuse, NY, USA           87M52VV2+M9
# 18                     NaN  2RXW+25 Syracuse, NY, USA           87M52RXW+25
# 19                   False  2RXW+CJ Syracuse, NY, USA           87M52RXW+CJ
#
#    permanently_closed
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                True
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
#
# [20 rows x 22 columns]

# %% [markdown]
# ## Challenge 5
#
# Convert your dataframe back into a list of dict.
#
# 1. use `to_records()` to convert the dataframe in Challenge 4 back into a `list` of `dict`.
# 2. loop over the rows and print the bar name, rating, and whether it is open now,
#    for only those rows where the bar is open now.
#
# NOTE: The keys match the columns in the data frame.

# %%
for row in flat_gdf.to_records():
    print(row['name'], row['rating'], row['opening_hours.open_now'])
# Out:
# Kitty Hoyne's Irish Pub 4.6 True
# Phoebe's Restaurant & Coffee Lounge 4.6 False
# Blue Tusk 4.4 True
# Faegan's Cafe & Pub 4.3 False
# Syracuse Suds Factory 3.3 nan
# Saltine Warrior Sports Pub 4.0 True
# Al's Wine & Whiskey Lounge 4.6 False
# Trexx 4.1 False
# Guilfoil's Irish Pub 4.6 True
# The Hops Spot 4.4 False
# Maxwells 4.3 False
# Anything But Beer 4.5 False
# The Evergreen 4.5 False
# Weighlock Lounge 4.8 False
# Funk 'n Waffles 4.4 True
# Shaughnessy's Irish Pub 4.1 False
# The York 4.3 False
# Ale 'n' Angus Pub 4.5 True
# Bistro Elephant 4.4 nan
# Clinton Street Pub 4.0 False

# %%
# run this code to turn in your work!
from coursetools.submission import Submission
Submission().submit_now()
