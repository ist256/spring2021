# %% [markdown]
# # End-To-End Example: Today's Weather
#
# This example will input a location and then output today's current weather conditions at that location.
#
# To complete this example we will use the following API's
#
# - https://www.openstreetmap.org/ Geocode api to get GPS coordinates for a location eg. Syracuse, NY
# - https://openweathermap.org/ forecast api to get the currnt weather conditions for those GPS coordinates

# %%
# Todo list
# input a location eg. Syracuse, ny
# use the google geocode api to get a lat/lng
# use the darksky api and lat/lng to get current weather conditions
# output current weather conditions (temperature and summary (rain, snow, etc...))

# %%
import requests

# %%
def geocode(location):
    query_string = {'q' : location, 'format': 'json'}
    url='https://nominatim.openstreetmap.org/search' 
    response = requests.get(url, params = query_string)
    if response.ok:
        geodata = response.json()
        return geodata
    else:
        print("Error calling api!!!")
        print(response.text)
        
# Testing with syracuse, NY 
geocode('Syracuse, NY')
# Out:
# [{'place_id': 257841956,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 174916,
#   'boundingbox': ['42.9843709', '43.086102', '-76.2046029', '-76.074084'],
#   'lat': '43.0481221',
#   'lon': '-76.1474244',
#   'display_name': 'Syracuse, Onondaga County, New York, United States',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.6867762857760726,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png'},
#  {'place_id': 69010415,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'node',
#   'osm_id': 6241108067,
#   'boundingbox': ['43.0718312', '43.0818312', '-76.1744003', '-76.1644003'],
#   'lat': '43.0768312',
#   'lon': '-76.1694003',
#   'display_name': 'Syracuse, 131, NBT Bank Parkway, Syracuse, Onondaga County, New York, 13208, United States',
#   'class': 'railway',
#   'type': 'station',
#   'importance': 0.4272524353626238,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//transport_train_station2.p.20.png'},
#  {'place_id': 38569226,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'node',
#   'osm_id': 2997656284,
#   'boundingbox': ['43.0770382', '43.0771382', '-76.1700021', '-76.1699021'],
#   'lat': '43.0770882',
#   'lon': '-76.1699521',
#   'display_name': 'Syracuse, Walsh Circle, Syracuse, Onondaga County, New York, 13290, United States',
#   'class': 'railway',
#   'type': 'stop',
#   'importance': 0.11100000000000002}]

# %%
def getweather(lat,lon):
    key = '67f9d45c32dd086df27f2b7a90370a8e' # sign up for your own key at https://darksky.net/dev 
    query_string = { 'lat' : lat, 'lon': lon, 'appid' : key, 'units' : 'imperial'}
    url='https://api.openweathermap.org/data/2.5/onecall' 
    response = requests.get(url, params=query_string)
    #print (response.url)
    weather = response.json()
    return weather

# Testing with syracuse, NY coordinates
getweather( 43.0481221, -76.1474244 )
# Out:
# {'lat': 43.0481,
#  'lon': -76.1474,
#  'timezone': 'America/New_York',
#  'timezone_offset': -18000,
#  'current': {'dt': 1610994784,
#   'sunrise': 1610973078,
#   'sunset': 1611007110,
#   'temp': 30.04,
#   'feels_like': 18.68,
#   'pressure': 1007,
#   'humidity': 69,
#   'dew_point': 22.12,
#   'uvi': 0.63,
#   'clouds': 90,
#   'visibility': 10000,
#   'wind_speed': 11.5,
#   'wind_deg': 270,
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}]},
#  'minutely': [{'dt': 1610994840, 'precipitation': 0},
#   {'dt': 1610994900, 'precipitation': 0},
#   {'dt': 1610994960, 'precipitation': 0},
#   {'dt': 1610995020, 'precipitation': 0},
#   {'dt': 1610995080, 'precipitation': 0},
#   {'dt': 1610995140, 'precipitation': 0},
#   {'dt': 1610995200, 'precipitation': 0},
#   {'dt': 1610995260, 'precipitation': 0},
#   {'dt': 1610995320, 'precipitation': 0},
#   {'dt': 1610995380, 'precipitation': 0},
#   {'dt': 1610995440, 'precipitation': 0},
#   {'dt': 1610995500, 'precipitation': 0},
#   {'dt': 1610995560, 'precipitation': 0},
#   {'dt': 1610995620, 'precipitation': 0},
#   {'dt': 1610995680, 'precipitation': 0},
#   {'dt': 1610995740, 'precipitation': 0},
#   {'dt': 1610995800, 'precipitation': 0},
#   {'dt': 1610995860, 'precipitation': 0},
#   {'dt': 1610995920, 'precipitation': 0},
#   {'dt': 1610995980, 'precipitation': 0},
#   {'dt': 1610996040, 'precipitation': 0},
#   {'dt': 1610996100, 'precipitation': 0},
#   {'dt': 1610996160, 'precipitation': 0},
#   {'dt': 1610996220, 'precipitation': 0},
#   {'dt': 1610996280, 'precipitation': 0},
#   {'dt': 1610996340, 'precipitation': 0},
#   {'dt': 1610996400, 'precipitation': 0},
#   {'dt': 1610996460, 'precipitation': 0},
#   {'dt': 1610996520, 'precipitation': 0},
#   {'dt': 1610996580, 'precipitation': 0},
#   {'dt': 1610996640, 'precipitation': 0},
#   {'dt': 1610996700, 'precipitation': 0},
#   {'dt': 1610996760, 'precipitation': 0},
#   {'dt': 1610996820, 'precipitation': 0},
#   {'dt': 1610996880, 'precipitation': 0},
#   {'dt': 1610996940, 'precipitation': 0},
#   {'dt': 1610997000, 'precipitation': 0},
#   {'dt': 1610997060, 'precipitation': 0},
#   {'dt': 1610997120, 'precipitation': 0},
#   {'dt': 1610997180, 'precipitation': 0},
#   {'dt': 1610997240, 'precipitation': 0},
#   {'dt': 1610997300, 'precipitation': 0},
#   {'dt': 1610997360, 'precipitation': 0},
#   {'dt': 1610997420, 'precipitation': 0},
#   {'dt': 1610997480, 'precipitation': 0},
#   {'dt': 1610997540, 'precipitation': 0},
#   {'dt': 1610997600, 'precipitation': 0},
#   {'dt': 1610997660, 'precipitation': 0},
#   {'dt': 1610997720, 'precipitation': 0},
#   {'dt': 1610997780, 'precipitation': 0},
#   {'dt': 1610997840, 'precipitation': 0},
#   {'dt': 1610997900, 'precipitation': 0},
#   {'dt': 1610997960, 'precipitation': 0},
#   {'dt': 1610998020, 'precipitation': 0},
#   {'dt': 1610998080, 'precipitation': 0},
#   {'dt': 1610998140, 'precipitation': 0},
#   {'dt': 1610998200, 'precipitation': 0},
#   {'dt': 1610998260, 'precipitation': 0},
#   {'dt': 1610998320, 'precipitation': 0},
#   {'dt': 1610998380, 'precipitation': 0},
#   {'dt': 1610998440, 'precipitation': 0}],
#  'hourly': [{'dt': 1610992800,
#    'temp': 30.04,
#    'feels_like': 19.47,
#    'pressure': 1007,
#    'humidity': 69,
#    'dew_point': 22.12,
#    'uvi': 0.86,
#    'clouds': 90,
#    'visibility': 1621,
#    'wind_speed': 10.07,
#    'wind_deg': 294,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.33},
#   {'dt': 1610996400,
#    'temp': 29.77,
#    'feels_like': 19.96,
#    'pressure': 1007,
#    'humidity': 83,
#    'dew_point': 25.77,
#    'uvi': 0.63,
#    'clouds': 95,
#    'visibility': 1699,
#    'wind_speed': 9.53,
#    'wind_deg': 295,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'pop': 0.38,
#    'snow': {'1h': 0.11}},
#   {'dt': 1611000000,
#    'temp': 29.48,
#    'feels_like': 20.16,
#    'pressure': 1008,
#    'humidity': 91,
#    'dew_point': 27.45,
#    'uvi': 0.32,
#    'clouds': 98,
#    'visibility': 3793,
#    'wind_speed': 9.06,
#    'wind_deg': 292,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.18},
#   {'dt': 1611003600,
#    'temp': 28.96,
#    'feels_like': 19.76,
#    'pressure': 1010,
#    'humidity': 95,
#    'dew_point': 27.86,
#    'uvi': 0.1,
#    'clouds': 99,
#    'visibility': 2356,
#    'wind_speed': 8.95,
#    'wind_deg': 291,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'pop': 0.32,
#    'snow': {'1h': 0.11}},
#   {'dt': 1611007200,
#    'temp': 28.02,
#    'feels_like': 19.42,
#    'pressure': 1010,
#    'humidity': 96,
#    'dew_point': 27.14,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 1950,
#    'wind_speed': 7.74,
#    'wind_deg': 290,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.12},
#   {'dt': 1611010800,
#    'temp': 27.91,
#    'feels_like': 19.33,
#    'pressure': 1011,
#    'humidity': 96,
#    'dew_point': 24.89,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 2336,
#    'wind_speed': 7.7,
#    'wind_deg': 283,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.08},
#   {'dt': 1611014400,
#    'temp': 27.95,
#    'feels_like': 19.65,
#    'pressure': 1012,
#    'humidity': 96,
#    'dew_point': 24.6,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 6591,
#    'wind_speed': 7.2,
#    'wind_deg': 277,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.08},
#   {'dt': 1611018000,
#    'temp': 27.45,
#    'feels_like': 20.08,
#    'pressure': 1013,
#    'humidity': 96,
#    'dew_point': 23.72,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 5.44,
#    'wind_deg': 266,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.1},
#   {'dt': 1611021600,
#    'temp': 27.43,
#    'feels_like': 19.94,
#    'pressure': 1013,
#    'humidity': 95,
#    'dew_point': 23.34,
#    'uvi': 0,
#    'clouds': 96,
#    'visibility': 10000,
#    'wind_speed': 5.59,
#    'wind_deg': 255,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.02},
#   {'dt': 1611025200,
#    'temp': 27.43,
#    'feels_like': 19.69,
#    'pressure': 1014,
#    'humidity': 96,
#    'dew_point': 23.85,
#    'uvi': 0,
#    'clouds': 97,
#    'visibility': 10000,
#    'wind_speed': 6.08,
#    'wind_deg': 250,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.11},
#   {'dt': 1611028800,
#    'temp': 26.28,
#    'feels_like': 18.73,
#    'pressure': 1014,
#    'humidity': 96,
#    'dew_point': 23.02,
#    'uvi': 0,
#    'clouds': 97,
#    'visibility': 10000,
#    'wind_speed': 5.5,
#    'wind_deg': 237,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.14},
#   {'dt': 1611032400,
#    'temp': 25.47,
#    'feels_like': 17.71,
#    'pressure': 1015,
#    'humidity': 96,
#    'dew_point': 22.41,
#    'uvi': 0,
#    'clouds': 97,
#    'visibility': 10000,
#    'wind_speed': 5.7,
#    'wind_deg': 236,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.15},
#   {'dt': 1611036000,
#    'temp': 25.97,
#    'feels_like': 18.28,
#    'pressure': 1015,
#    'humidity': 97,
#    'dew_point': 23.18,
#    'uvi': 0,
#    'clouds': 97,
#    'visibility': 9406,
#    'wind_speed': 5.75,
#    'wind_deg': 239,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.13},
#   {'dt': 1611039600,
#    'temp': 26.46,
#    'feels_like': 19.33,
#    'pressure': 1015,
#    'humidity': 97,
#    'dew_point': 23.95,
#    'uvi': 0,
#    'clouds': 99,
#    'visibility': 8118,
#    'wind_speed': 4.85,
#    'wind_deg': 236,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.06},
#   {'dt': 1611043200,
#    'temp': 26.78,
#    'feels_like': 19.76,
#    'pressure': 1015,
#    'humidity': 97,
#    'dew_point': 24.62,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 2086,
#    'wind_speed': 4.72,
#    'wind_deg': 235,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.25},
#   {'dt': 1611046800,
#    'temp': 27.21,
#    'feels_like': 20.57,
#    'pressure': 1015,
#    'humidity': 97,
#    'dew_point': 25.25,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 531,
#    'wind_speed': 4.14,
#    'wind_deg': 227,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13n'}],
#    'pop': 0.25,
#    'snow': {'1h': 0.17}},
#   {'dt': 1611050400,
#    'temp': 27.34,
#    'feels_like': 20.35,
#    'pressure': 1015,
#    'humidity': 97,
#    'dew_point': 25.29,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 793,
#    'wind_speed': 4.76,
#    'wind_deg': 219,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.3},
#   {'dt': 1611054000,
#    'temp': 27.86,
#    'feels_like': 19.9,
#    'pressure': 1015,
#    'humidity': 97,
#    'dew_point': 25.29,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 5485,
#    'wind_speed': 6.62,
#    'wind_deg': 227,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.3},
#   {'dt': 1611057600,
#    'temp': 27.61,
#    'feels_like': 18.82,
#    'pressure': 1015,
#    'humidity': 97,
#    'dew_point': 25.12,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 1073,
#    'wind_speed': 8.03,
#    'wind_deg': 236,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.32},
#   {'dt': 1611061200,
#    'temp': 28,
#    'feels_like': 19.09,
#    'pressure': 1016,
#    'humidity': 96,
#    'dew_point': 24.98,
#    'uvi': 0,
#    'clouds': 99,
#    'visibility': 10000,
#    'wind_speed': 8.3,
#    'wind_deg': 233,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.17},
#   {'dt': 1611064800,
#    'temp': 28.96,
#    'feels_like': 18.9,
#    'pressure': 1016,
#    'humidity': 96,
#    'dew_point': 25.03,
#    'uvi': 0.22,
#    'clouds': 97,
#    'visibility': 10000,
#    'wind_speed': 10.54,
#    'wind_deg': 236,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.24},
#   {'dt': 1611068400,
#    'temp': 30.31,
#    'feels_like': 19.62,
#    'pressure': 1016,
#    'humidity': 95,
#    'dew_point': 25.34,
#    'uvi': 0.45,
#    'clouds': 99,
#    'visibility': 10000,
#    'wind_speed': 11.92,
#    'wind_deg': 239,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.25},
#   {'dt': 1611072000,
#    'temp': 31.48,
#    'feels_like': 20.97,
#    'pressure': 1016,
#    'humidity': 94,
#    'dew_point': 26.1,
#    'uvi': 0.75,
#    'clouds': 99,
#    'visibility': 10000,
#    'wind_speed': 11.81,
#    'wind_deg': 245,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.26},
#   {'dt': 1611075600,
#    'temp': 32.07,
#    'feels_like': 21.72,
#    'pressure': 1015,
#    'humidity': 94,
#    'dew_point': 26.87,
#    'uvi': 0.86,
#    'clouds': 99,
#    'visibility': 10000,
#    'wind_speed': 11.68,
#    'wind_deg': 244,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.26},
#   {'dt': 1611079200,
#    'temp': 31.98,
#    'feels_like': 22.21,
#    'pressure': 1015,
#    'humidity': 96,
#    'dew_point': 27.84,
#    'uvi': 0.78,
#    'clouds': 99,
#    'visibility': 3734,
#    'wind_speed': 10.76,
#    'wind_deg': 238,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.21},
#   {'dt': 1611082800,
#    'temp': 32.09,
#    'feels_like': 22.42,
#    'pressure': 1014,
#    'humidity': 96,
#    'dew_point': 28.99,
#    'uvi': 0.62,
#    'clouds': 100,
#    'visibility': 724,
#    'wind_speed': 10.58,
#    'wind_deg': 241,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'pop': 0.42,
#    'snow': {'1h': 0.13}},
#   {'dt': 1611086400,
#    'temp': 32.41,
#    'feels_like': 22.46,
#    'pressure': 1014,
#    'humidity': 95,
#    'dew_point': 28.54,
#    'uvi': 0.31,
#    'clouds': 100,
#    'visibility': 1541,
#    'wind_speed': 11.12,
#    'wind_deg': 251,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'pop': 0.48,
#    'snow': {'1h': 0.19}},
#   {'dt': 1611090000,
#    'temp': 31.51,
#    'feels_like': 21.72,
#    'pressure': 1015,
#    'humidity': 96,
#    'dew_point': 28.35,
#    'uvi': 0.1,
#    'clouds': 100,
#    'visibility': 2291,
#    'wind_speed': 10.65,
#    'wind_deg': 251,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'pop': 0.48,
#    'snow': {'1h': 0.35}},
#   {'dt': 1611093600,
#    'temp': 30.81,
#    'feels_like': 20.41,
#    'pressure': 1015,
#    'humidity': 96,
#    'dew_point': 27.55,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 4337,
#    'wind_speed': 11.59,
#    'wind_deg': 257,
#    'weather': [{'id': 601,
#      'main': 'Snow',
#      'description': 'snow',
#      'icon': '13n'}],
#    'pop': 0.58,
#    'snow': {'1h': 0.62}},
#   {'dt': 1611097200,
#    'temp': 30.49,
#    'feels_like': 19.63,
#    'pressure': 1015,
#    'humidity': 95,
#    'dew_point': 25.56,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 12.24,
#    'wind_deg': 256,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13n'}],
#    'pop': 0.72,
#    'snow': {'1h': 0.31}},
#   {'dt': 1611100800,
#    'temp': 28.87,
#    'feels_like': 18.37,
#    'pressure': 1015,
#    'humidity': 94,
#    'dew_point': 23.72,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 11.16,
#    'wind_deg': 248,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.76},
#   {'dt': 1611104400,
#    'temp': 27.45,
#    'feels_like': 16.03,
#    'pressure': 1015,
#    'humidity': 95,
#    'dew_point': 23.2,
#    'uvi': 0,
#    'clouds': 98,
#    'visibility': 5913,
#    'wind_speed': 12.55,
#    'wind_deg': 262,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.52},
#   {'dt': 1611108000,
#    'temp': 26.67,
#    'feels_like': 15.78,
#    'pressure': 1015,
#    'humidity': 94,
#    'dew_point': 21.65,
#    'uvi': 0,
#    'clouds': 96,
#    'visibility': 10000,
#    'wind_speed': 11.41,
#    'wind_deg': 263,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.57},
#   {'dt': 1611111600,
#    'temp': 25.32,
#    'feels_like': 14.05,
#    'pressure': 1015,
#    'humidity': 93,
#    'dew_point': 19.58,
#    'uvi': 0,
#    'clouds': 79,
#    'visibility': 10000,
#    'wind_speed': 11.79,
#    'wind_deg': 259,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0.56},
#   {'dt': 1611115200,
#    'temp': 23.79,
#    'feels_like': 13.17,
#    'pressure': 1015,
#    'humidity': 94,
#    'dew_point': 18.59,
#    'uvi': 0,
#    'clouds': 65,
#    'visibility': 10000,
#    'wind_speed': 10.38,
#    'wind_deg': 254,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0.57},
#   {'dt': 1611118800,
#    'temp': 23.04,
#    'feels_like': 12.16,
#    'pressure': 1015,
#    'humidity': 94,
#    'dew_point': 17.85,
#    'uvi': 0,
#    'clouds': 54,
#    'visibility': 10000,
#    'wind_speed': 10.69,
#    'wind_deg': 248,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0.57},
#   {'dt': 1611122400,
#    'temp': 22.41,
#    'feels_like': 11.32,
#    'pressure': 1014,
#    'humidity': 93,
#    'dew_point': 17.06,
#    'uvi': 0,
#    'clouds': 47,
#    'visibility': 10000,
#    'wind_speed': 10.94,
#    'wind_deg': 248,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0.59},
#   {'dt': 1611126000,
#    'temp': 22.23,
#    'feels_like': 11.07,
#    'pressure': 1014,
#    'humidity': 93,
#    'dew_point': 16.72,
#    'uvi': 0,
#    'clouds': 77,
#    'visibility': 10000,
#    'wind_speed': 11.03,
#    'wind_deg': 249,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0.41},
#   {'dt': 1611129600,
#    'temp': 22.71,
#    'feels_like': 11.1,
#    'pressure': 1014,
#    'humidity': 93,
#    'dew_point': 17.1,
#    'uvi': 0,
#    'clouds': 89,
#    'visibility': 10000,
#    'wind_speed': 11.9,
#    'wind_deg': 249,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.41},
#   {'dt': 1611133200,
#    'temp': 22.53,
#    'feels_like': 10.89,
#    'pressure': 1014,
#    'humidity': 94,
#    'dew_point': 17.28,
#    'uvi': 0,
#    'clouds': 92,
#    'visibility': 10000,
#    'wind_speed': 11.99,
#    'wind_deg': 252,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.41},
#   {'dt': 1611136800,
#    'temp': 22.84,
#    'feels_like': 10.6,
#    'pressure': 1014,
#    'humidity': 94,
#    'dew_point': 17.74,
#    'uvi': 0,
#    'clouds': 94,
#    'visibility': 10000,
#    'wind_speed': 13.09,
#    'wind_deg': 260,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13n'}],
#    'pop': 0.41,
#    'snow': {'1h': 0.13}},
#   {'dt': 1611140400,
#    'temp': 22.95,
#    'feels_like': 10.24,
#    'pressure': 1015,
#    'humidity': 95,
#    'dew_point': 19.06,
#    'uvi': 0,
#    'clouds': 95,
#    'visibility': 1759,
#    'wind_speed': 14,
#    'wind_deg': 271,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13n'}],
#    'pop': 0.41,
#    'snow': {'1h': 0.25}},
#   {'dt': 1611144000,
#    'temp': 22.91,
#    'feels_like': 10.94,
#    'pressure': 1016,
#    'humidity': 96,
#    'dew_point': 19.47,
#    'uvi': 0,
#    'clouds': 96,
#    'visibility': 3347,
#    'wind_speed': 12.71,
#    'wind_deg': 289,
#    'weather': [{'id': 601,
#      'main': 'Snow',
#      'description': 'snow',
#      'icon': '13n'}],
#    'pop': 0.61,
#    'snow': {'1h': 0.68}},
#   {'dt': 1611147600,
#    'temp': 22.87,
#    'feels_like': 10.38,
#    'pressure': 1016,
#    'humidity': 93,
#    'dew_point': 17.44,
#    'uvi': 0.07,
#    'clouds': 99,
#    'visibility': 5809,
#    'wind_speed': 13.49,
#    'wind_deg': 314,
#    'weather': [{'id': 601,
#      'main': 'Snow',
#      'description': 'snow',
#      'icon': '13d'}],
#    'pop': 0.38,
#    'snow': {'1h': 0.86}},
#   {'dt': 1611151200,
#    'temp': 22.33,
#    'feels_like': 9.03,
#    'pressure': 1017,
#    'humidity': 92,
#    'dew_point': 15.69,
#    'uvi': 0.26,
#    'clouds': 98,
#    'visibility': 10000,
#    'wind_speed': 14.81,
#    'wind_deg': 309,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'pop': 0.43,
#    'snow': {'1h': 0.18}},
#   {'dt': 1611154800,
#    'temp': 22.59,
#    'feels_like': 8.78,
#    'pressure': 1017,
#    'humidity': 91,
#    'dew_point': 14.83,
#    'uvi': 0.53,
#    'clouds': 98,
#    'visibility': 10000,
#    'wind_speed': 15.7,
#    'wind_deg': 306,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'pop': 0.51,
#    'snow': {'1h': 0.11}},
#   {'dt': 1611158400,
#    'temp': 22.91,
#    'feels_like': 8.64,
#    'pressure': 1017,
#    'humidity': 89,
#    'dew_point': 14.07,
#    'uvi': 0.84,
#    'clouds': 95,
#    'visibility': 10000,
#    'wind_speed': 16.51,
#    'wind_deg': 304,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.54},
#   {'dt': 1611162000,
#    'temp': 23.18,
#    'feels_like': 8.69,
#    'pressure': 1018,
#    'humidity': 89,
#    'dew_point': 13.86,
#    'uvi': 0.97,
#    'clouds': 93,
#    'visibility': 10000,
#    'wind_speed': 16.91,
#    'wind_deg': 302,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.56}],
#  'daily': [{'dt': 1610989200,
#    'sunrise': 1610973078,
#    'sunset': 1611007110,
#    'temp': {'day': 30.04,
#     'min': 26.28,
#     'max': 32.41,
#     'night': 26.28,
#     'eve': 27.91,
#     'morn': 29.89},
#    'feels_like': {'day': 20.59, 'night': 18.73, 'eve': 19.33, 'morn': 22.42},
#    'pressure': 1007,
#    'humidity': 96,
#    'dew_point': 26.85,
#    'wind_speed': 9.71,
#    'wind_deg': 292,
#    'weather': [{'id': 601,
#      'main': 'Snow',
#      'description': 'snow',
#      'icon': '13d'}],
#    'clouds': 100,
#    'pop': 0.93,
#    'snow': 3.44,
#    'uvi': 0.96},
#   {'dt': 1611075600,
#    'sunrise': 1611059441,
#    'sunset': 1611093585,
#    'temp': {'day': 32.07,
#     'min': 23.79,
#     'max': 32.41,
#     'night': 23.79,
#     'eve': 30.49,
#     'morn': 27.86},
#    'feels_like': {'day': 21.72, 'night': 13.17, 'eve': 19.63, 'morn': 19.9},
#    'pressure': 1015,
#    'humidity': 94,
#    'dew_point': 26.87,
#    'wind_speed': 11.68,
#    'wind_deg': 244,
#    'weather': [{'id': 601,
#      'main': 'Snow',
#      'description': 'snow',
#      'icon': '13d'}],
#    'clouds': 99,
#    'pop': 0.76,
#    'snow': 1.77,
#    'uvi': 0.86},
#   {'dt': 1611162000,
#    'sunrise': 1611145801,
#    'sunset': 1611180060,
#    'temp': {'day': 23.18,
#     'min': 17.55,
#     'max': 23.18,
#     'night': 18.3,
#     'eve': 19.18,
#     'morn': 22.95},
#    'feels_like': {'day': 8.69, 'night': 9.05, 'eve': 10.63, 'morn': 10.24},
#    'pressure': 1018,
#    'humidity': 89,
#    'dew_point': 13.86,
#    'wind_speed': 16.91,
#    'wind_deg': 302,
#    'weather': [{'id': 601,
#      'main': 'Snow',
#      'description': 'snow',
#      'icon': '13d'}],
#    'clouds': 93,
#    'pop': 0.61,
#    'snow': 2.21,
#    'uvi': 0.97},
#   {'dt': 1611248400,
#    'sunrise': 1611232160,
#    'sunset': 1611266537,
#    'temp': {'day': 34.88,
#     'min': 19.47,
#     'max': 35.02,
#     'night': 31.39,
#     'eve': 31.46,
#     'morn': 27.97},
#    'feels_like': {'day': 24.33, 'night': 21.63, 'eve': 23.34, 'morn': 16.09},
#    'pressure': 1001,
#    'humidity': 93,
#    'dew_point': 33.1,
#    'wind_speed': 12.66,
#    'wind_deg': 246,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'clouds': 100,
#    'pop': 0.62,
#    'snow': 1.17,
#    'uvi': 0.76},
#   {'dt': 1611334800,
#    'sunrise': 1611318516,
#    'sunset': 1611353014,
#    'temp': {'day': 31.17,
#     'min': 23.41,
#     'max': 31.17,
#     'night': 23.41,
#     'eve': 24.78,
#     'morn': 29.07},
#    'feels_like': {'day': 17.73, 'night': 11.48, 'eve': 13.37, 'morn': 16.86},
#    'pressure': 1005,
#    'humidity': 96,
#    'dew_point': 27.34,
#    'wind_speed': 17.07,
#    'wind_deg': 279,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'clouds': 92,
#    'pop': 0.98,
#    'snow': 4.22,
#    'uvi': 1.12},
#   {'dt': 1611421200,
#    'sunrise': 1611404870,
#    'sunset': 1611439492,
#    'temp': {'day': 17.89,
#     'min': 13.33,
#     'max': 20.41,
#     'night': 13.33,
#     'eve': 14.47,
#     'morn': 16.09},
#    'feels_like': {'day': 5.65, 'night': 5.59, 'eve': 6.19, 'morn': 3.61},
#    'pressure': 1027,
#    'humidity': 93,
#    'dew_point': 12.58,
#    'wind_speed': 12.28,
#    'wind_deg': 309,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'clouds': 100,
#    'pop': 0.83,
#    'snow': 2.33,
#    'uvi': 2},
#   {'dt': 1611507600,
#    'sunrise': 1611491223,
#    'sunset': 1611525970,
#    'temp': {'day': 18.19,
#     'min': 6.15,
#     'max': 18.93,
#     'night': 18.48,
#     'eve': 17.69,
#     'morn': 6.15},
#    'feels_like': {'day': 12.38, 'night': 10.24, 'eve': 10.27, 'morn': -0.42},
#    'pressure': 1030,
#    'humidity': 85,
#    'dew_point': 6.69,
#    'wind_speed': 0.63,
#    'wind_deg': 346,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': 67,
#    'pop': 0,
#    'uvi': 2},
#   {'dt': 1611594000,
#    'sunrise': 1611577573,
#    'sunset': 1611612449,
#    'temp': {'day': 33.22,
#     'min': 21.07,
#     'max': 35.47,
#     'night': 26.94,
#     'eve': 35.2,
#     'morn': 26.13},
#    'feels_like': {'day': 24.08, 'night': 17.15, 'eve': 24.67, 'morn': 15.53},
#    'pressure': 1002,
#    'humidity': 93,
#    'dew_point': 30.42,
#    'wind_speed': 9.75,
#    'wind_deg': 154,
#    'weather': [{'id': 616,
#      'main': 'Snow',
#      'description': 'rain and snow',
#      'icon': '13d'}],
#    'clouds': 100,
#    'pop': 1,
#    'rain': 5.62,
#    'snow': 4.56,
#    'uvi': 2}]}

# %%
# then test them here to figue out how to extract from the dictionary
geodata = geocode('Syracuse, NY')
lat = geodata[0]['lat']
lon = geodata[0]['lon']
weather = getweather(lat, lon)
weather['current']
# Out:
# {'dt': 1610994784,
#  'sunrise': 1610973078,
#  'sunset': 1611007110,
#  'temp': 30.04,
#  'feels_like': 18.68,
#  'pressure': 1007,
#  'humidity': 69,
#  'dew_point': 22.12,
#  'uvi': 0.63,
#  'clouds': 90,
#  'visibility': 10000,
#  'wind_speed': 11.5,
#  'wind_deg': 270,
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}]}

# %%
import requests
# Now I can write the entire program...
location = input("Where are you? (eg. Syracuse, NY) : ")
geodata = geocode(location)
lat,lon = geodata[0]['lat'], geodata[0]['lon']
weather = getweather(lat,lon)
current = weather['current']
print(f"Current conditions in {location} are {current['weather'][0]['description']} with a temperature of {current['temp']} degrees.")
# Out:
# Where are you? (eg. Syracuse, NY) :  Syracuse, NY
# Current conditions in Syracuse, NY are overcast clouds with a temperature of 30.04 degrees.

# %%
from IPython.display import display, HTML
from ipywidgets import interact_manual
import requests

display(HTML("<h1>Weather Forecaster</h1>"))
@interact_manual(location="")
def main(location):
    geodata = geocode(location)
    lat,lon = geodata[0]['lat'], geodata[0]['lon']
    weather = getweather(lat,lon)
    current = weather['current']
    print(f"Current conditions in {location} are {current['weather'][0]['description']} with a temperature of {current['temp']} degrees.")
# Out:
# <h1>Weather Forecaster</h1>
# interactive(children=(Text(value='', description='location'), Button(description='Run Interact', style=ButtonS…
