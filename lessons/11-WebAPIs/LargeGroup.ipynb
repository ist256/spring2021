# %% [markdown]
# # Code Samples From Large Group

# %%
import requests

key = '76A0D6DF-3FEF-4D5D-A4A7-2AA0CC48E068'
url = "http://rest.coinapi.io/" #"https://rest-sandbox.coinapi.io/"
headers = { 'X-CoinAPI-Key' : key }
query_string = { 'apikey' : key}
endpoint = "v1/exchangerate/BTC"
fullurl = f"{url}{endpoint}"
response = requests.get(fullurl, params=query_string)
response.raise_for_status()
print(response.url)
data =response.json()

for item in data['rates']:
    print(item['asset_id_quote'], f"{item['rate']:.2f}")
# Out:
# http://rest.coinapi.io/v1/exchangerate/BTC?apikey=76A0D6DF-3FEF-4D5D-A4A7-2AA0CC48E068
# $PAC 4653035.46
# 18C 10240119.08
# 1GOLD 946.58
# 1INCH 11185.58
# 1INCH3L 314993.99
# 1INCH3S 107835.75
# 1INCH5L 451918.31
# 1INCH5S 63510.03
# 1MT 78308.54
# 1ST 11899.38
# 2KEY 1016778.75
# 3BBEAR 155579.10
# 3BBULL 42.81
# 4ART 494783.75
# 520 32671943.71
# 777 454545.45
# 7E 28472140280.52
# 7UP 34274.84
# 888 123134.13
# 88MPH 422.47
# 8PAY 140249.81
# A5T 116609.13
# AAB 99488.02
# AAC 3517838.59
# AAL 2608.82
# AAPL 417.03
# AAPX 2904.01
# AAVE 155.72
# AAVE3L 8486.55
# AAVE3S 842359.92
# AAVEDOWN 48604.44
# AAVEUP 3374.99
# ABBC 399965.36
# ABC 14483568.54
# ABL 1854867.53
# ABNB 322.91
# ABP 89937.17
# ABS 72597887.70
# ABT 215734.62
# ABYSS 881057.27
# AC 18422.73
# ACAT 43730836.85
# ACB 6834.17
# ACD 1224754.48
# ACE 254203.04
# ACH 5568684.76
# ACM 5372.35
# ACM2 5372.33
# ACMFT 5234.16
# ACT 2217235.35
# ACT1 4887889.52
# ACU 2673555.74
# ACXT 96974.32
# ADA 45603.05
# ...

# %%
item
# Out:
# {'time': '2021-04-19T21:03:00.0000000Z',
#  'asset_id_quote': 'ZYX',
#  'rate': 5920324.667647235}
